# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep=sc.fit_transform(indep)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'max_features': ['sqrt', 'log2', None],
    'n_estimators': [50, 100]
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)

re=grid.cv_results_

#print(re)
grid_predictions = grid.predict(indep)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}: 0.9771793439927312

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.193926      0.008344         0.007993        0.000442
# 1        0.370328      0.011000         0.012505        0.000318
# 2        0.180606      0.006037         0.007594        0.000964
# 3        0.353531      0.001357         0.014402        0.001933
# 4        0.241185      0.013543         0.007692        0.001464
# 5        0.494132      0.033491         0.014599        0.002588
# 6        0.205411      0.011309         0.008390        0.001278
# 7        0.385510      0.033272         0.013196        0.000679
# 8        0.199274      0.027332         0.007012        0.000901
# 9        0.362425      0.010888         0.014101        0.002041
# 10       0.234681      0.011290         0.007494        0.001415
# 11       0.506627      0.055855         0.013191        0.000869
# 12       0.622388      0.028551         0.006699        0.000664
# 13       1.252858      0.085328         0.012891        0.001362
# 14       0.611625      0.017055         0.007005        0.001342
# 15       1.300100      0.072039         0.015894        0.007814
# 16       1.050711      0.062029         0.007891        0.001395
# 17       2.032476      0.052580         0.013089        0.001164
# 18       0.212061      0.014860         0.006906        0.000484
# 19       0.437478      0.018176         0.015998        0.003612
# 20       0.228189      0.021555         0.006490        0.001047
# 21       0.437520      0.027389         0.013592        0.000796
# 22       0.304664      0.024686         0.006898        0.000743
# 23       0.452463      0.009692         0.008895        0.001851
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error               None                 50
# 5    squared_error               None                100
# 6     friedman_mse               sqrt                 50
# 7     friedman_mse               sqrt                100
# 8     friedman_mse               log2                 50
# 9     friedman_mse               log2                100
# 10    friedman_mse               None                 50
# 11    friedman_mse               None                100
# 12  absolute_error               sqrt                 50
# 13  absolute_error               sqrt                100
# 14  absolute_error               log2                 50
# 15  absolute_error               log2                100
# 16  absolute_error               None                 50
# 17  absolute_error               None                100
# 18         poisson               sqrt                 50
# 19         poisson               sqrt                100
# 20         poisson               log2                 50
# 21         poisson               log2                100
# 22         poisson               None                 50
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.857921
# 1   {'criterion': 'squared_error', 'max_features':...           0.860408
# 2   {'criterion': 'squared_error', 'max_features':...           0.860551
# 3   {'criterion': 'squared_error', 'max_features':...           0.859694
# 4   {'criterion': 'squared_error', 'max_features':...           0.857786
# 5   {'criterion': 'squared_error', 'max_features':...           0.847089
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.854678
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.860690
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.859031
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857284
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.845716
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.849963
# 12  {'criterion': 'absolute_error', 'max_features'...           0.852950
# 13  {'criterion': 'absolute_error', 'max_features'...           0.859169
# 14  {'criterion': 'absolute_error', 'max_features'...           0.858599
# 15  {'criterion': 'absolute_error', 'max_features'...           0.858450
# 16  {'criterion': 'absolute_error', 'max_features'...           0.835568
# 17  {'criterion': 'absolute_error', 'max_features'...           0.844143
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860709
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.863919
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.858811
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.859999
# 22  {'criterion': 'poisson', 'max_features': None,...           0.847954
# 23  {'criterion': 'poisson', 'max_features': None,...           0.850511
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.780656           0.860089           0.822906
# 1            0.784024           0.862943           0.826877
# 2            0.772049           0.856516           0.822647
# 3            0.783029           0.860255           0.831649
# 4            0.762609           0.854603           0.819745
# 5            0.770733           0.857209           0.815704
# 6            0.775937           0.856326           0.832479
# 7            0.783423           0.861570           0.824984
# 8            0.773583           0.866955           0.828804
# 9            0.778711           0.865020           0.826615
# 10           0.766898           0.853873           0.816528
# 11           0.773666           0.858281           0.815522
# 12           0.781811           0.864882           0.825883
# 13           0.778962           0.859263           0.832308
# 14           0.779431           0.859499           0.824648
# 15           0.779149           0.855341           0.824555
# 16           0.776693           0.853418           0.824420
# 17           0.760867           0.853895           0.827824
# 18           0.777780           0.856840           0.826638
# 19           0.777019           0.860370           0.829900
# 20           0.775998           0.866855           0.828538
# 21           0.776113           0.863707           0.827075
# 22           0.774281           0.852742           0.820536
# 23           0.775801           0.853579           0.818098
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.840134         0.832341        0.029139               14
# 1            0.841365         0.835124        0.028745                2
# 2            0.847927         0.831938        0.032715               16
# 3            0.842238         0.835373        0.028325                1
# 4            0.836733         0.826295        0.034643               19
# 5            0.840357         0.826219        0.030936               20
# 6            0.843730         0.832630        0.029614               12
# 7            0.841379         0.834409        0.028863                5
# 8            0.837308         0.833136        0.032854               10
# 9            0.847007         0.834928        0.030921                4
# 10           0.838833         0.824370        0.031304               24
# 11           0.842107         0.827908        0.030679               17
# 12           0.843545         0.833814        0.028960                8
# 13           0.840712         0.834083        0.029491                7
# 14           0.845331         0.833502        0.029825                9
# 15           0.843187         0.832136        0.029045               15
# 16           0.836133         0.825246        0.025988               22
# 17           0.837503         0.824846        0.033102               23
# 18           0.841728         0.832739        0.030006               11
# 19           0.843612         0.834964        0.031439                3
# 20           0.832514         0.832543        0.031877               13
# 21           0.844678         0.834314        0.031846                6
# 22           0.835386         0.826180        0.028248               21
# 23           0.839979         0.827594        0.028728               18

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 33
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
preinput=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
preinput
# Out:
# C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.1539595 ,  0.38330685,  0.75107928, -1.0105187 ,  1.97058663]])

# %%
Future_Prediction=grid.predict(preinput)

#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36322.8443953]
