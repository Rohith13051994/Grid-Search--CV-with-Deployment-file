# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
'max_features': ['sqrt', 'log2', None],
'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(X_train, y_train)

# Print best parameters after tuning
print("Best parameters:", grid.best_params_)

# Predictions
grid_predictions = grid.predict(X_test)

# Print R2 score
from sklearn.metrics import r2_score
r_score = r2_score(y_test, grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)

# Results table
import pandas as pd
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}: 0.7121852487133584

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003401      0.000854         0.000799        0.000399
# 1        0.002700      0.000680         0.000803        0.000401
# 2        0.002406      0.000374         0.000998        0.000001
# 3        0.002302      0.000409         0.000997        0.000002
# 4        0.003398      0.000585         0.000802        0.000401
# 5        0.002798      0.000809         0.000901        0.000197
# 6        0.002393      0.000489         0.000501        0.000635
# 7        0.002009      0.000321         0.000801        0.000401
# 8        0.002299      0.000508         0.001000        0.000002
# 9        0.001698      0.000398         0.000599        0.000489
# 10       0.003021      0.000552         0.000399        0.000489
# 11       0.002306      0.000619         0.000598        0.000488
# 12       0.010992      0.001406         0.000599        0.000489
# 13       0.008402      0.000863         0.000607        0.000496
# 14       0.010818      0.001437         0.000799        0.000399
# 15       0.009207      0.000883         0.000598        0.000489
# 16       0.016296      0.002906         0.000599        0.000489
# 17       0.013401      0.002662         0.000600        0.000490
# 18       0.003095      0.000487         0.000000        0.000000
# 19       0.002300      0.000610         0.000599        0.000489
# 20       0.003502      0.001054         0.000199        0.000399
# 21       0.002606      0.000591         0.000199        0.000399
# 22       0.003990      0.000633         0.000500        0.000446
# 23       0.002398      0.000374         0.000400        0.000490
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.528675
# 1   {'criterion': 'squared_error', 'max_features':...           0.597059
# 2   {'criterion': 'squared_error', 'max_features':...           0.669222
# 3   {'criterion': 'squared_error', 'max_features':...           0.621732
# 4   {'criterion': 'squared_error', 'max_features':...           0.680419
# 5   {'criterion': 'squared_error', 'max_features':...           0.589359
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.481895
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.700006
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.530394
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.305150
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.704093
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.698476
# 12  {'criterion': 'absolute_error', 'max_features'...           0.510515
# 13  {'criterion': 'absolute_error', 'max_features'...           0.590855
# 14  {'criterion': 'absolute_error', 'max_features'...           0.029925
# 15  {'criterion': 'absolute_error', 'max_features'...           0.720992
# 16  {'criterion': 'absolute_error', 'max_features'...           0.639902
# 17  {'criterion': 'absolute_error', 'max_features'...           0.703066
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0